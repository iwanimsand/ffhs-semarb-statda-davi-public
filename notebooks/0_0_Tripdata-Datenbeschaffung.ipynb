# %% [markdown]
# FFHS DAS Data Science
# Semesterarbeit FS20
# Iwan Imsand

# %% [markdown]
# # Datenbeschaffung ```tripdata```

# %% [markdown]
# # Einleitung

# %% [markdown]
# In diesem Notebook werden die nötigen Tripdaten beschafft.
#
# Tripdaten sind hierbei Systemdaten über die einzelnen Fahrten die von [Citi Bike NYC](https://www.citibikenyc.com/) zur Verfügung gestellt werden. Unter [System Data](https://www.citibikenyc.com/system-data) werden die Verfügbaren Daten detaillierter beschrieben.

# %% [markdown]
# # Amazon S3 Bucket Helper

# %% [markdown]
# Die Daten werden über [Amazone Simple Storage Service (Amazon S3)](https://aws.amazon.com/s3/) in sogenannten [Amazon S3 Buckets](https://docs.aws.amazon.com/AmazonS3/latest/dev/UsingBucket.html) zur Verfügung gestellt. In diesem Abschnitt wird eine Hilfsklasse erstellt, um den späteren Code zu vereinfachen und Details über Amazon S3 Buckets zu abstrahieren.

# %%
import os
from io import BytesIO
from zipfile import ZipFile

import boto3
import requests
from botocore import UNSIGNED
from botocore.config import Config


class S3Helper:
    
    
    def __init__(self):
        # see https://www.edureka.co/community/10528/is-there-any-way-to-use-boto3-anonymously
        self.s3_client = boto3.client('s3', config=Config(signature_version=UNSIGNED))        
    
    
    def bucket_items_iterator(self, bucket, key_filter=lambda key: key):
        """
        Generator that iterates over all objects in a given s3 bucket

        See http://boto3.readthedocs.io/en/latest/reference/services/s3.html#S3.Client.list_objects_v2
        for return data format
        :param bucket: name of s3 bucket
        :param key_filter: lambda function for filtering keys
        :return: dict of metadata for an object
        """

        paginator = self.s3_client.get_paginator('list_objects_v2')
        page_iterator = paginator.paginate(Bucket=bucket)

        for page in page_iterator:
            if page['KeyCount'] > 0:
                for item in page['Contents']:
                    if key_filter(item['Key']):
                        yield item


    def get_url(self, bucket, item):
        """
        Evaluates the download url for an item in the bucket content.

        :param bucket: name of s3 bucket
        :param item: item from the content of the s3 bucket
        :return: the download url for the given item
        """

        url = '{}/{}/{}'.format(self.s3_client.meta.endpoint_url, bucket, item['Key'])
        return url


    def zip_extract(self, url, path, file_filter=lambda file: file, filename_rename=lambda filename: filename):
        """
        Extracts the content of a zip file.

        :param url: the url
        :param path: the destination folder (will be created if not exists)
        :param file_filter: lambda function for filtering files in zip
        :param filename_rename: lambda function for renaming files when extracting
        """

        print('Downloading {}\n'.format(url))

        content = requests.get(url)
        zip_ref = ZipFile(BytesIO(content.content))
        zip_info_matches = [zip_info for zip_info in zip_ref.infolist() if file_filter(zip_info.filename)]

        try:
            for zip_info in zip_info_matches:
                try:
                    if not os.path.exists(path):
                        os.makedirs(path)
                    old_filename = zip_info.filename
                    new_filename = filename_rename(zip_info.filename)
                    print('Extracting {} from {} to {}/{}'.format(zip_info.filename, url, path, new_filename))
                    zip_info.filename = new_filename
                    zip_ref.extract(member=zip_info, path=path)
                except Exception as e:
                    print('ERROR for file {}/{}: {}', url, old_filename, e)

        finally:
            zip_ref.close()

# %%
s3 = S3Helper()

# %% [markdown]
# # Herunterladen und entpacken

# %% [markdown]
# Ab hier wird das eigentliche Herunterladen und entpacken aller Dateien erledigt. Damit dies schneller vonstatten geht, wurde das Herunterladen mit mehreren Prozessen parallelisiert.

# %%
import multiprocessing as mp
import re

# %%
# extract all files to this path
path = './../data/citibike/tripdata/src'

# the name of the bucket, see https://s3.amazonaws.com/tripdata/index.html
bucket = 'tripdata'

# filter the files in the bucket and download only files matching the given regular expression
key_filter_regex = '^[0-9]{4}.*\\.zip' # All zip files starting with 4 numbers.
#key_filter_regex = '^201910.*\\.zip' # Only the files of october 2019

# %%
def file_filter(filename):
    """
    Exclude files/folders from extraction. Some zip files contain files we want to ignore.
    
    :param filename: the filename to test
    """
    
    return not filename.startswith('__')

# %%
def filename_rename(filename):
    """
    Renames a filename and aligns it to schema like '201910-citibike-tripdata.csv'
    
    :param filename: the filename to align to the schema
    """
    
    marker = 'citibike-tripdata'
    if re.match('^[0-9]{6}.*\\.csv', filename):
        return '{}-{}.csv'.format(filename[0:6], marker)
    elif re.match('^[0-9]{4}-[0-9]{2}.*\\.csv', filename):
        return '{}{}-{}.csv'.format(filename[0:4], filename[5:7], marker)
    else:
        print('ERROR: No matching found for {}_{}.'.format(item['Key'], filename))

# %%
def download_and_extract(item):
    """
    Downlaods and extracts an item in the bucket.
    
    :param item: the bucket item
    """
    url = s3.get_url(bucket=bucket, item=item)
    s3.zip_extract(url=url, path=path, file_filter=file_filter, filename_rename=filename_rename)

# %% [markdown]
# Mit Hilfe der oben definierten Funktionen, wird nun in der folgenden Zelle alles heruntergeladen und entpackt.
#
# **ACHTUNG: Die Grösse der entpackten Daten beträgt ca. 20GB! <font color='red'>Daher nicht auf einem langsamen oder mit wenig Speicherplatz ausgestattetem System ausführen!</font>**

# %%
items_iterator = s3.bucket_items_iterator(bucket=bucket, key_filter=lambda k: re.match(key_filter_regex, k))

try:
    # see https://www.machinelearningplus.com/python/parallel-processing-python/
    pool = mp.Pool(mp.cpu_count())
    pool.map(func=download_and_extract, iterable=items_iterator)
finally:
    pool.close()
    
print("*** Completed! ***")
# Out:
# Downloading https://s3.amazonaws.com/tripdata/201308-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201307-201402-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201306-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201307-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201311-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201310-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201309-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201402-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201401-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201404-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201312-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201405-citibike-tripdata.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201403-citibike-tripdata.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201406-citibike-tripdata.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201407-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201408-citibike-tripdata.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201409-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201410-citibike-tripdata.zip
#
#
#
#
#
# Downloading https://s3.amazonaws.com/tripdata/201411-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201412-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201502-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201503-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201505-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201506-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201504-citibike-tripdata.zip
#
#
# Downloading https://s3.amazonaws.com/tripdata/201512-citibike-tripdata.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201511-citibike-tripdata.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201510-citibike-tripdata.zip
#
#
# Downloading https://s3.amazonaws.com/tripdata/201501-citibike-tripdata.zip
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Downloading https://s3.amazonaws.com/tripdata/201507-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201509-citibike-tripdata.zip
# Downloading https://s3.amazonaws.com/tripdata/201508-citibike-tripdata.zip
#
#
#
# Extracting 201502-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201502-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201502-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201601-citibike-tripdata.zip
#
# Extracting 2014-01 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201401-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201401-citibike-tripdata.csv
# Extracting 201501-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201501-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201501-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201602-citibike-tripdata.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201603-citibike-tripdata.zip
#
# Extracting 201412-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201412-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201412-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201604-citibike-tripdata.zip
#
# Extracting 201503-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201503-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201503-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201605-citibike-tripdata.zip
#
# Extracting 201601-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201601-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201601-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201606-citibike-tripdata.zip
#
# Extracting 201411-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201411-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201411-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201607-citibike-tripdata.zip
#
# Extracting 201603-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201603-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201603-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201608-citibike-tripdata.zip
#
# Extracting 201602-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201602-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201602-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201609-citibike-tripdata.zip
#
# Extracting 2014-05 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201405-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201405-citibike-tripdata.csv
# Extracting 201511-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201511-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201511-citibike-tripdata.csv
# Extracting 2013-07 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201307-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201307-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201610-citibike-tripdata.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201611-citibike-tripdata.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201612-citibike-tripdata.zip
#
# Extracting 201508-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201508-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201508-citibike-tripdata.csv
# Extracting 2013-10 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201310-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201310-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201701-citibike-tripdata.csv.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201702-citibike-tripdata.csv.zip
#
# Extracting 2013-08 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201308-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201308-citibike-tripdata.csv
# Extracting 2014-02 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201402-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201402-citibike-tripdata.csv
# Extracting 201606-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201606-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201606-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201703-citibike-tripdata.csv.zip
#
# Extracting 2013-12 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201312-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201312-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201704-citibike-tripdata.csv.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201705-citibike-tripdata.csv.zip
#
# Extracting 201512-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201512-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201512-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201706-citibike-tripdata.csv.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201707-citibike-tripdata.csv.zip
#
# Extracting 2013-11 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201311-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201311-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201708-citibike-tripdata.csv.zip
#
# Extracting 201306-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201306-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201306-citibike-tripdata.csv
# Extracting 2014-04 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201404-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201404-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201709-citibike-tripdata.csv.zip
#
# Extracting 201604-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201604-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201604-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201710-citibike-tripdata.csv.zip
#
# Extracting 201701-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201701-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201701-citibike-tripdata.csv
# Extracting 201702-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201702-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201702-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201711-citibike-tripdata.csv.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201712-citibike-tripdata.csv.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201801-citibike-tripdata.csv.zip
#
# Extracting 2014-03 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201403-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201403-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201802-citibike-tripdata.csv.zip
#
# Extracting 201610-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201610-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201610-citibike-tripdata.csv
# Extracting 201703-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201703-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201703-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201803-citibike-tripdata.csv.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201804-citibike-tripdata.csv.zip
#
# Extracting 201801-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201801-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201801-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201805-citibike-tripdata.csv.zip
#
# Extracting 201712-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201712-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201712-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201806-citibike-tripdata.csv.zip
#
# Extracting 201802-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201802-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201802-citibike-tripdata.csv
# Extracting 201711-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201711-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201711-citibike-tripdata.csv
# Extracting 201607-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201607-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201607-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201807-citibike-tripdata.csv.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201808-citibike-tripdata.csv.zip
#
# Extracting 201611-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201611-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201611-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201809-citibike-tripdata.csv.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201810-citibike-tripdata.csv.zip
#
# Extracting 201504-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201504-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201504-citibike-tripdata.csv
# Extracting 201710-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201710-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201710-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201811-citibike-tripdata.csv.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201812-citibike-tripdata.csv.zip
#
# Extracting 201803-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201803-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201803-citibike-tripdata.csv
# Extracting 201506-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201506-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201506-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201901-citibike-tripdata.csv.zip
#
# Extracting 2013-09 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201309-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201309-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201902-citibike-tripdata.csv.zip
#
# Extracting 201608-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201608-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201608-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201903-citibike-tripdata.csv.zip
#
# Extracting 201804-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201804-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201804-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201904-citibike-tripdata.csv.zip
#
# Extracting 201612-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201612-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201612-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201905-citibike-tripdata.csv.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201906-citibike-tripdata.csv.zip
#
# Extracting 201805-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201805-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201805-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201907-citibike-tripdata.csv.zip
#
# Extracting 2014-08 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201408-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201408-citibike-tripdata.csv
# Extracting 2014-06 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201406-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201406-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201908-citibike-tripdata.csv.zip
#
# Downloading https://s3.amazonaws.com/tripdata/201909-citibike-tripdata.csv.zip
#
# Extracting 201901-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201901-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201901-citibike-tripdata.csv
# Extracting 201505-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201505-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201505-citibike-tripdata.csv
# Extracting 201707-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201707-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201707-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201910-citibike-tripdata.csv.zip
#
# Extracting 201507-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201507-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201507-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201911-citibike-tripdata.csv.zip
#
# Extracting 201410-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201410-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201410-citibike-tripdata.csv
# Extracting 201706-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201706-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201706-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/201912-citibike-tripdata.csv.zip
#
# Downloading https://s3.amazonaws.com/tripdata/202001-citibike-tripdata.csv.zip
#
# Downloading https://s3.amazonaws.com/tripdata/202002-citibike-tripdata.csv.zip
#
# Downloading https://s3.amazonaws.com/tripdata/202003-citibike-tripdata.csv.zip
#
# Extracting 2014-07 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201407-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201407-citibike-tripdata.csv
# Downloading https://s3.amazonaws.com/tripdata/202004-citibike-tripdata.csv.zip
#
# Extracting 201510-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201510-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201510-citibike-tripdata.csv
# Extracting 201509-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201509-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201509-citibike-tripdata.csv
# Extracting 201806-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201806-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201806-citibike-tripdata.csv
# Extracting 201902-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201902-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201902-citibike-tripdata.csv
# Extracting 201609-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201609-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201609-citibike-tripdata.csv
# Extracting 201812-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201812-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201812-citibike-tripdata.csv
# Extracting 201906-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201906-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201906-citibike-tripdata.csv
# Extracting 201708-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201708-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201708-citibike-tripdata.csv
# Extracting 202001-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/202001-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/202001-citibike-tripdata.csv
# Extracting 202002-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/202002-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/202002-citibike-tripdata.csv
# Extracting 202004-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/202004-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/202004-citibike-tripdata.csv
# Extracting 201605-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201605-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201605-citibike-tripdata.csv
# Extracting 201911-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201911-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201911-citibike-tripdata.csv
# Extracting 201811-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201811-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201811-citibike-tripdata.csv
# Extracting 201912-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201912-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201912-citibike-tripdata.csv
# Extracting 201704-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201704-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201704-citibike-tripdata.csv
# Extracting 201907-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201907-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201907-citibike-tripdata.csv
# Extracting 201807-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201807-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201807-citibike-tripdata.csv
# Extracting 201904-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201904-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201904-citibike-tripdata.csv
# Extracting 201409-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201409-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201409-citibike-tripdata.csv
# Extracting 201910-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201910-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201910-citibike-tripdata.csv
# Extracting 201705-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201705-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201705-citibike-tripdata.csv
# Extracting 201709-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201709-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201709-citibike-tripdata.csv
# Extracting 201809-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201809-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201809-citibike-tripdata.csv
# Extracting 202003-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/202003-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/202003-citibike-tripdata.csv
# Extracting 201908-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201908-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201908-citibike-tripdata.csv
# Extracting 201903-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201903-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201903-citibike-tripdata.csv
# Extracting 201810-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201810-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201810-citibike-tripdata.csv
# Extracting 201909-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201909-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201909-citibike-tripdata.csv
# Extracting 201905-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201905-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201905-citibike-tripdata.csv
# Extracting 201808-citibike-tripdata.csv from https://s3.amazonaws.com/tripdata/201808-citibike-tripdata.csv.zip to ./../data/citibike/tripdata/src/201808-citibike-tripdata.csv
# Extracting 2014-02 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201307-201402-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201402-citibike-tripdata.csv
# Extracting 2014-01 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201307-201402-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201401-citibike-tripdata.csv
# Extracting 2013-12 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201307-201402-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201312-citibike-tripdata.csv
# Extracting 2013-11 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201307-201402-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201311-citibike-tripdata.csv
# Extracting 2013-10 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201307-201402-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201310-citibike-tripdata.csv
# Extracting 2013-09 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201307-201402-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201309-citibike-tripdata.csv
# Extracting 2013-08 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201307-201402-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201308-citibike-tripdata.csv
# Extracting 2013-07 - Citi Bike trip data.csv from https://s3.amazonaws.com/tripdata/201307-201402-citibike-tripdata.zip to ./../data/citibike/tripdata/src/201307-citibike-tripdata.csv
# *** Completed! ***
